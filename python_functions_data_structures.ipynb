# %% [markdown]
# # Built-In Data Structures, Functions, and Files

# %% [markdown]
# ## Data Structures and Sequences

# %% [markdown]
# #### 1) Tuple
# A tuple is a fixed-length, immutable sequence of Python objects which, once assigned, cannot be changed.

# %%
# create tuple
tup = (1, 2, 3)
tup
# Out:
# (1, 2, 3)

# %%
# we can ommit parenthesis
tup2 = 1, 2, 3
tup2
# Out:
# (1, 2, 3)

# %%
# convert seqs into tuple
tuple([1, 2, 3, 4])
# Out:
# (1, 2, 3, 4)

# %%
# convert seqs into tuple
name = 'oktavianus'
name_tup = tuple(name)
name_tup
# Out:
# ('o', 'k', 't', 'a', 'v', 'i', 'a', 'n', 'u', 's')

# %%
# accessing element using square brackets
name_tup[4]
# Out:
# 'v'

# %%
# nested tup
nested_tup = (1, 2, 3), (4, 5, 6)
nested_tup
# Out:
# ((1, 2, 3), (4, 5, 6))

# %%
len(nested_tup)
# Out:
# 2

# %%
# accessing nested tup
nested_tup[1]
# Out:
# (4, 5, 6)
